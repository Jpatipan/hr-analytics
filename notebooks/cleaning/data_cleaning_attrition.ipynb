# %%
import pandas as pd

# %%
hr_attrition_data = pd.read_csv('../../data/raw/hr_attrition_data.csv')
hr_attrition_data
# Out:
#     EmployeeID   Department  Gender    Education  SatisfactionLevel  \
# 0        E1000      Finance    Male  High School                2.5
# 1        E1001      Finance    Male  High School                4.8
# 2        E1002           HR  Female     Bachelor                3.9
# 3        E1003  Engineering    Male     Bachelor                3.4
# 4        E1004      Finance    Male          PhD                1.6
# ..         ...          ...     ...          ...                ...
# 295      E1295           HR  Female          PhD                3.1
# 296      E1296        Sales    Male  High School                4.1
# 297      E1297      Finance    Male  High School                1.9
# 298      E1298      Finance    Male     Bachelor                3.5
# 299      E1299    Marketing  Female       Master                1.3
#
#      YearsAtCompany  MonthlyIncome Attrition
# 0                 3          20404        No
# 1                 2          60943       Yes
# ...

# %%
# check the data is null
data_null = hr_attrition_data.isnull().sum()
data_null
# Out:
# EmployeeID           0
# Department           0
# Gender               0
# Education            0
# SatisfactionLevel    0
# YearsAtCompany       0
# MonthlyIncome        0
# Attrition            0
# dtype: int64

# %%
# check the data is na
data_na = hr_attrition_data.isna().sum()
data_na
# Out:
# EmployeeID           0
# Department           0
# Gender               0
# Education            0
# SatisfactionLevel    0
# YearsAtCompany       0
# MonthlyIncome        0
# Attrition            0
# dtype: int64

# %%
# check the data types
hr_attrition_data.dtypes
# Out:
# EmployeeID            object
# Department            object
# Gender                object
# Education             object
# SatisfactionLevel    float64
# YearsAtCompany         int64
# MonthlyIncome          int64
# Attrition             object
# dtype: object

# %%
hr_attrition_data
# Out:
#     EmployeeID   Department  Gender    Education  SatisfactionLevel  \
# 0        E1000      Finance    Male  High School                2.5
# 1        E1001      Finance    Male  High School                4.8
# 2        E1002           HR  Female     Bachelor                3.9
# 3        E1003  Engineering    Male     Bachelor                3.4
# 4        E1004      Finance    Male          PhD                1.6
# ..         ...          ...     ...          ...                ...
# 295      E1295           HR  Female          PhD                3.1
# 296      E1296        Sales    Male  High School                4.1
# 297      E1297      Finance    Male  High School                1.9
# 298      E1298      Finance    Male     Bachelor                3.5
# 299      E1299    Marketing  Female       Master                1.3
#
#      YearsAtCompany  MonthlyIncome Attrition
# 0                 3          20404        No
# 1                 2          60943       Yes
# ...

# %%
# rename the columns
hr_attrition_data = hr_attrition_data.rename(columns={
    'EmployeeID': 'employee_id',
    'Department': 'department',
    'Gender': 'gender',
    'Education': 'education',
    'SatisfactionLevel': 'satisfaction',
    'YearsAtCompany': 'work_experience',
    'MonthlyIncome': 'salary',
    'Attrition': 'attrition',})

hr_attrition_data
# Out:
#     employee_id   department  gender    education  satisfaction  \
# 0         E1000      Finance    Male  High School           2.5
# 1         E1001      Finance    Male  High School           4.8
# 2         E1002           HR  Female     Bachelor           3.9
# 3         E1003  Engineering    Male     Bachelor           3.4
# 4         E1004      Finance    Male          PhD           1.6
# ..          ...          ...     ...          ...           ...
# 295       E1295           HR  Female          PhD           3.1
# 296       E1296        Sales    Male  High School           4.1
# 297       E1297      Finance    Male  High School           1.9
# 298       E1298      Finance    Male     Bachelor           3.5
# 299       E1299    Marketing  Female       Master           1.3
#
#      work_experience  salary attrition
# 0                  3   20404        No
# 1                  2   60943       Yes
# 2                  6   67926        No
# ...

# %%
# export the data to csv
df = pd.DataFrame(hr_attrition_data)
df.to_csv('../../data/processed/hr_attrition_data.csv', index=False)
print("Data saved to ../data/processed/hr_attrition_data.csv")
# Out:
# Data saved to ../data/processed/hr_attrition_data.csv
